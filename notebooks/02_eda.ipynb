# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/sentiment_project/processed_reviews.csv')

# %%
df['rating'].value_counts(normalize=True).plot(kind='bar', title='Rating Distribution')
# Out:
# <Axes: title={'center': 'Rating Distribution'}, xlabel='rating'>

# %%
df['label'].value_counts(normalize=True).plot(kind='bar', title='Sentiment Distribution')
# Out:
# <Axes: title={'center': 'Sentiment Distribution'}, xlabel='label'>

# %%
class_counts = df['label'].value_counts()
# Calculer le pourcentage de chaque classe
class_percentages = (class_counts / len(df)) * 100

# Afficher les résultats
print(class_percentages)
# Out:
# label
# positive    72.245640
# negative    19.161318
# neutral      8.593042
# Name: count, dtype: float64

# %%
sns.countplot(x='label', data=df)
plt.title("Distribution of Sentiment Classes")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()

# %%
df['text_length'] = df['full_text'].apply(lambda x: len(str(x).split()))

# Average length per sentiment
df.groupby('label')['text_length'].mean()

# Histogram of text lengths
sns.histplot(data=df, x='text_length', bins=50, hue='label', element="step")
plt.title("Text Length Distribution by Sentiment")
plt.show()

# %%
import joblib
joblib.dump(svm_model, '/content/drive/MyDrive/sentiment_project/svm_model.pkl')
joblib.dump(random_forest_model, '/content/drive/MyDrive/sentiment_project/rf_model.pkl')
